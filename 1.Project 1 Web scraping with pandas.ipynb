# %%
import pandas as pd

# %% [markdown]
# ## Target website: https://www.football-data.co.uk/data.php

# %%
#Reading the  csv file from the site 
dataF = pd.read_csv(r"https://www.football-data.co.uk/mmz4281/2526/E0.csv")

# %% [markdown]
# # Read a .csv file from a URL with Pandas

# %%
dataF.head()
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth     4     2   H     1
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle     0     0   D     0
# 2  E0  16/08/2025  15:00     Brighton       Fulham     1     1   D     0
# 3  E0  16/08/2025  15:00   Sunderland     West Ham     3     0   H     0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley     3     0   H     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1     0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2     0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3     0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4     0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.76     2.14     1.86
# 1     1.74     2.14     1.86
# ...

# %%
#renaming the columns
dataF.rename(columns={ 'FTHG' :'home_goals',
               'FTAG': 'away_goals' }, inplace = True)

# %%
dataF
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  home_goals  \
# 0    E0  15/08/2025  20:00      Liverpool  Bournemouth           4
# 1    E0  16/08/2025  12:30    Aston Villa    Newcastle           0
# 2    E0  16/08/2025  15:00       Brighton       Fulham           1
# 3    E0  16/08/2025  15:00     Sunderland     West Ham           3
# 4    E0  16/08/2025  15:00      Tottenham      Burnley           3
# ..   ..         ...    ...            ...          ...         ...
# 375  E0  24/05/2026  16:00       Man City  Aston Villa           1
# 376  E0  24/05/2026  16:00  Nott'm Forest  Bournemouth           1
# 377  E0  24/05/2026  16:00     Sunderland      Chelsea           2
# 378  E0  24/05/2026  16:00      Tottenham      Everton           1
# 379  E0  24/05/2026  16:00       West Ham        Leeds           3
#
#      away_goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0             2   H     1     0  ...     2.03     1.78   2.07   1.85     2.03
# ...

# %% [markdown]
# # Read .csv from Multiple Urls with pandas

# %% [markdown]
# ### Link:root + season + league

# %%
#link structure/ every link has a smilar part instead of parts
"https://www.football-data.co.uk/mmz4281/" + "2526" + "/" + "E0" + ".csv"
# Out:
# 'https://www.football-data.co.uk/mmz4281/2526/E0.csv'

# %%
#root variable link/ the part of the link i.e same for every other links
root = "https://www.football-data.co.uk/mmz4281/"

# %% [markdown]
# ## Multiple leagues
# ### 1.https://www.football-data.co.uk/mmz4281/2122/E0.csv
# ### 2.https://www.football-data.co.uk/mmz4281/2122/E1.csv
# ### 3.https://www.football-data.co.uk/mmz4281/2122/E2.csv
# ### 4.https://www.football-data.co.uk/mmz4281/2122/E3.csv
# ### 5.https://www.football-data.co.uk/mmz4281/2122/EC.csv

# %%
#creating list of leagues
leagues = ['E0', 'E1', 'E2', 'E3', 'EC']
frames = []           #a list

#looping through leagues, read multiple csv and append in into a list
for league in leagues:
    df = pd.read_csv( root + '2122' + '/' + league + '.csv', encoding ='unicode_escape')
    frames.append(df)    #to store each df when a new iteration begins as the old df will be lost (to protect them use append)

# %%
# length of frames (total intems in a element)
len(frames)
# Out:
# 5

# %%
#checking index of frames and seeing the DFs enterned
frames[4]
# Out:
#     Div        Date   Time        HomeTeam      AwayTeam  FTHG  FTAG FTR  \
# 0    EC  21/08/2021  15:00       Aldershot  Chesterfield     0     2   A
# 1    EC  21/08/2021  15:00          Barnet  Notts County     0     5   A
# 2    EC  21/08/2021  15:00         Halifax    Maidenhead     1     2   A
# 3    EC  21/08/2021  15:00     Kings Lynn      Southend     0     1   A
# 4    EC  21/08/2021  15:00        Solihull       Wrexham     2     2   D
# ..   ..         ...    ...             ...           ...   ...   ...  ..
# 501  EC  15/05/2022  15:00  Dover Athletic      Weymouth     1     2   A
# 502  EC  15/05/2022  15:00       Eastleigh       Grimsby     4     4   D
# 503  EC  15/05/2022  15:00      Maidenhead  Notts County     0     1   A
# 504  EC  15/05/2022  15:00        Southend       Torquay     1     1   D
# 505  EC  15/05/2022  15:00       Stockport       Halifax     2     0   H
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# ...

# %% [markdown]
# ## 2.2 Multiple Seasons (now extracting data for multiple seasons)

# %%
for season in range(15, 21):
    print(str(season) + str(season+1))
# Out:
# 1516
# 1617
# 1718
# 1819
# 1920
# 2021

# %%
#creating list of leagues
leagues = ['E0', 'E1', 'E2']
frames = []           #a list

#looping through leagues, read multiple csv and append in into a list
for league in leagues:
    for season in range(15, 21):
        df = pd.read_csv( root + str(season) + str(season+1) + '/' + league + '.csv',)
        df.insert(1,'season',season)
        frames.append(df)

# %%
#total frames (6 seasons x 3 leagues)
len(frames)
# Out:
# 18

# %%
frames[0]
# Out:
#     Div  season        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0      15  08/08/2015  Bournemouth  Aston Villa     0     1   A     0
# 1    E0      15  08/08/2015      Chelsea      Swansea     2     2   D     2
# 2    E0      15  08/08/2015      Everton      Watford     2     2   D     0
# 3    E0      15  08/08/2015    Leicester   Sunderland     4     2   H     3
# 4    E0      15  08/08/2015   Man United    Tottenham     1     0   H     1
# ..   ..     ...         ...          ...          ...   ...   ...  ..   ...
# 375  E0      15  15/05/2016        Stoke     West Ham     2     1   H     0
# 376  E0      15  15/05/2016      Swansea     Man City     1     1   D     1
# 377  E0      15  15/05/2016      Watford   Sunderland     2     2   D     0
# 378  E0      15  15/05/2016    West Brom    Liverpool     1     1   D     1
# 379  E0      15  17/05/2016   Man United  Bournemouth     3     1   H     1
#
# ...

# %%
frames[5]
# Out:
#     Div  season        Date   Time          HomeTeam        AwayTeam  FTHG  \
# 0    E0      20  12/09/2020  12:30            Fulham         Arsenal     0
# 1    E0      20  12/09/2020  15:00    Crystal Palace     Southampton     1
# 2    E0      20  12/09/2020  17:30         Liverpool           Leeds     4
# 3    E0      20  12/09/2020  20:00          West Ham       Newcastle     0
# 4    E0      20  13/09/2020  14:00         West Brom       Leicester     0
# ..   ..     ...         ...    ...               ...             ...   ...
# 375  E0      20  23/05/2021  16:00         Liverpool  Crystal Palace     2
# 376  E0      20  23/05/2021  16:00          Man City         Everton     5
# 377  E0      20  23/05/2021  16:00  Sheffield United         Burnley     1
# 378  E0      20  23/05/2021  16:00          West Ham     Southampton     3
# 379  E0      20  23/05/2021  16:00            Wolves      Man United     1
#
# ...

# %% [markdown]
# # 3.Organize all the data in a dictionary

# %%
import pandas as pd

# %%
# creat a dictionary with original name of the league as key 
dict_countries={ 'Spanish La Liga':'SP1', 'Spanish Segunda Division':'SP2',
                  'Gernman Bundesliga':'D1', 'English Premier League':'E0',
                  'English League 1': 'E2'
}

# %%
#get a dict element
dict_countries['Spanish La Liga']
# Out:
# 'SP1'

# %%
#loop through key elements
dict_historical_data = {}

# %%
for league in dict_countries:
    print(dict_countries[league])
# Out:
# SP1
# SP2
# D1
# E0
# E2

# %%
#creating list of leagues
#leagues = ['E0', 'E1', 'E2']
frames = []          

#looping through leagues, read multiple csv and append in into a list
for league in dict_countries:
    for season in range(15, 21):
        df = pd.read_csv( root + str(season) + str(season+1) + '/' + dict_countries[league] + '.csv',)
        df.insert(1,'season',season)
        frames.append(df) 
    df_concat = pd.concat(frames)
    dict_historical_data[league] = df_concat

# %%
#show keys of the df
dict_historical_data.keys()
# Out:
# dict_keys(['Spanish La Liga', 'Spanish Segunda Division', 'Gernman Bundesliga', 'English Premier League', 'English League 1'])

# %%
#show dataframe inside dict_historical_data
dict_historical_data['Gernman Bundesliga']   #better than keeping the index in mind and remembering the code
# Out:
#      Div  season        Date       HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    SP1      15    21/08/15         Malaga     Sevilla     0     0   D   0.0
# 1    SP1      15    22/08/15     Ath Madrid  Las Palmas     1     0   H   1.0
# 2    SP1      15    22/08/15        Espanol      Getafe     1     0   H   1.0
# 3    SP1      15    22/08/15      La Coruna    Sociedad     0     0   D   0.0
# 4    SP1      15    22/08/15      Vallecano    Valencia     0     0   D   0.0
# ..   ...     ...         ...            ...         ...   ...   ...  ..   ...
# 301   D1      20  22/05/2021     Hoffenheim      Hertha     2     1   H   0.0
# 302   D1      20  22/05/2021      Stuttgart   Bielefeld     0     2   A   0.0
# 303   D1      20  22/05/2021   Union Berlin  RB Leipzig     2     1   H   0.0
# 304   D1      20  22/05/2021  Werder Bremen  M'gladbach     2     4   A   0.0
# 305   D1      20  22/05/2021      Wolfsburg       Mainz     2     3   A   0.0
#
# ...
